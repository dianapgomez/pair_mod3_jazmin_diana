# %% [markdown]
# ## Pair Programing
# # Estadística Descriptiva
#
# Eres un analista de datos que trabaja para una organización internacional que se enfoca en el desarrollo y el bienestar de los países. Tu objetivo es realizar un análisis inicial de estadísticas descriptivas sobre varios países utilizando el conjunto de datos proporcionado.
#
# - Objetivo: Realizar un análisis de estadísticas descriptivas para comprender mejor la situación de los países en términos de diversos indicadores.
#
# - Instrucciones:
#
#     - Calcula las siguientes estadísticas descriptivas para las variables numéricas:
#
#         - Media
#
#         - Mediana
#
#         - Desviación estándar
#
#         - Mínimo
#
#         - Máximo
#
#     - Identifica el país con la mayor densidad de población y el país con la menor población en el conjunto de datos.
#
#     - Calcula la tasa promedio de natalidad (birth_rate) para todos los países en el conjunto de datos.
#
#     - Realiza un análisis de la mortalidad infantil (infant_mortality) y clasifica los países en tres categorías: baja, moderada y alta mortalidad infantil.
#
#     - Calcula la correlación entre las variables de "fertility_rate" y "life_expectancy". Interpreta la relación entre estas dos variables. ¿Qué tipo de correlación hay? Explica la razón de esta relación

# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluar linealidad de las relaciones entre las variables
# ------------------------------------------------------------------------------
from scipy.stats import shapiro, kstest

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("world_data_full_apply_nulos.csv", index_col=0)

df.head()
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1    652.230
# 1      Albania    105.0           AL               43.1     28.748
# 2      Algeria     18.0           DZ               17.4        NaN
# 3      Andorra    164.0           AD               40.0    468.000
# 4       Angola     26.0           AO               47.5        NaN
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
# 2              317.0       24.28         213.0            Algiers
# 3                NaN        7.20         376.0   Andorra la Vella
# 4              117.0       40.73         244.0             Luanda
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0          8.672  149.90         2.3           AFN            4.47
# 1          4.536  119.05         1.4           ALL            1.62
# 2        150.006  151.36         2.0           DZD            3.02
# 3        469.000     NaN         NaN           EUR            1.27
# 4         34.693  261.73        17.1           AOA            5.52
#
#    forested_area  gasoline_price           gdp  \
# 0            2.1            0.70  1.910135e+10
# 1           28.1            1.36  1.527808e+10
# 2            0.8            0.28  1.699882e+11
# 3           34.0            1.51  3.154058e+09
# 4           46.3            0.97  9.463542e+10
#
#    gross_primary_education_enrollment  gross_tertiary_education_enrollment  \
# 0                               104.0                                  9.7
# 1                               107.0                                 55.0
# 2                               109.9                                 51.4
# 3                               106.4                                  NaN
# 4                               113.5                                  9.3
#
#    infant_mortality      largest_city  life_expectancy  \
# 0              47.9             Kabul             64.5
# 1               7.8            Tirana             78.5
# 2              20.1           Algiers             76.7
# 3               2.7  Andorra la Vella              NaN
# 4              51.6            Luanda             60.8
#
#    maternal_mortality_ratio  minimum_wage official_language  \
# 0                     638.0          0.43            Pashto
# 1                      15.0          1.12          Albanian
# 2                     112.0          0.95            Arabic
# 3                       NaN          6.63           Catalan
# 4                     241.0          0.71        Portuguese
#
#    out_of_pocket_health_expenditure  physicians_per_thousand  population  \
# 0                              78.4                     0.28         NaN
# 1                              56.9                     1.20         NaN
# 2                              28.1                     1.72         NaN
# 3                              36.4                     3.33      77.142
# 4                              33.4                     0.21         NaN
#
#    population_labor_force_participation  tax_revenue  total_tax_rate  \
# 0                                  48.9          9.3            71.4
# 1                                  55.7         18.6            36.6
# 2                                  41.2         37.2            66.1
# 3                                   NaN          NaN             NaN
# 4                                  77.5          9.2            49.1
#
#    unemployment_rate  urban_population   latitude  longitude continent
# 0              11.12               NaN  33.939110  67.709953      Asia
# 1              12.33               NaN  41.153332  20.168331    Europe
# 2              11.70               NaN  28.033886   1.659626    Africa
# 3                NaN            67.873  42.506285   1.521801    Europe
# 4               6.89               NaN -11.202692  17.873887    Africa

# %% [markdown]
# - Calcula las siguientes estadísticas descriptivas para las variables numéricas:
#
#     - Media
#
#     - Mediana
#
#     - Desviación estándar
#
#     - Mínimo
#
#     - Máximo

# %%
df.describe().T
# Out:
#                                       count          mean           std  \
# density                               195.0  1.345045e+02  1.573068e+02
# agricultural_land                     188.0  3.911755e+01  2.178305e+01
# land_area                             165.0  2.552127e+02  2.583850e+02
# armed_forces_size                     166.0  1.037831e+02  1.671580e+02
# birth_rate                            189.0  2.021497e+01  9.945774e+00
# calling_code                          194.0  3.605464e+02  3.232364e+02
# co2-emissions                         183.0  1.259155e+02  1.817949e+02
# cpi                                   175.0  1.441936e+02  5.478400e+01
# cpi_change                            179.0  6.722346e+00  2.445041e+01
# fertility_rate                        188.0  2.698138e+00  1.282267e+00
# forested_area                         188.0  3.201543e+01  2.379133e+01
# gasoline_price                        175.0  1.002457e+00  3.688585e-01
# gdp                                   193.0  4.772959e+11  2.172173e+12
# gross_primary_education_enrollment    188.0  1.024702e+02  1.315161e+01
# gross_tertiary_education_enrollment   183.0  3.796339e+01  2.926102e+01
# infant_mortality                      189.0  2.133280e+01  1.954806e+01
# life_expectancy                       187.0  7.227968e+01  7.483661e+00
# maternal_mortality_ratio              181.0  1.603923e+02  2.335020e+02
# minimum_wage                          150.0  2.194133e+00  2.970796e+00
# out_of_pocket_health_expenditure      188.0  3.263723e+01  1.917270e+01
# physicians_per_thousand               188.0  1.839840e+00  1.684261e+00
# population                             39.0  3.335427e+02  2.964675e+02
# population_labor_force_participation  176.0  6.273807e+01  1.050291e+01
# tax_revenue                           169.0  1.657396e+01  6.961632e+00
# total_tax_rate                        183.0  4.082240e+01  2.055766e+01
# unemployment_rate                     176.0  6.886364e+00  5.079216e+00
# urban_population                       45.0  2.794610e+02  2.833224e+02
# latitude                              194.0  1.909235e+01  2.396178e+01
# longitude                             194.0  2.023243e+01  6.671611e+01
#
#                                                min           25%  \
# density                               1.265000e+00  2.616850e+01
# agricultural_land                     6.000000e-01  2.170000e+01
# land_area                             0.000000e+00  4.127700e+01
# armed_forces_size                     0.000000e+00  1.025000e+01
# birth_rate                            5.900000e+00  1.130000e+01
# calling_code                          1.000000e+00  8.250000e+01
# co2-emissions                         1.016000e+00  7.600000e+00
# cpi                                   9.903000e+01  1.136700e+02
# cpi_change                           -4.300000e+00  1.000000e+00
# fertility_rate                        9.800000e-01  1.705000e+00
# forested_area                         0.000000e+00  1.100000e+01
# gasoline_price                        0.000000e+00  7.550000e-01
# gdp                                   4.727146e+07  8.454620e+09
# gross_primary_education_enrollment    2.340000e+01  9.895000e+01
# gross_tertiary_education_enrollment   8.000000e-01  1.215000e+01
# infant_mortality                      1.400000e+00  6.000000e+00
# life_expectancy                       5.280000e+01  6.700000e+01
# maternal_mortality_ratio              2.000000e+00  1.300000e+01
# minimum_wage                          1.000000e-02  4.025000e-01
# out_of_pocket_health_expenditure      2.000000e-01  1.745000e+01
# physicians_per_thousand               1.000000e-02  3.325000e-01
# population                            1.008400e+01  8.713000e+01
# population_labor_force_participation  3.800000e+01  5.615000e+01
# tax_revenue                           0.000000e+00  1.170000e+01
# total_tax_rate                        8.000000e+00  3.060000e+01
# unemployment_rate                     9.000000e-02  3.395000e+00
# urban_population                      5.464000e+00  4.076500e+01
# latitude                             -4.090056e+01  4.544175e+00
# longitude                            -1.751982e+02 -7.941496e+00
#
#                                                50%           75%           max
# density                               8.300000e+01  1.655000e+02  8.470000e+02
# agricultural_land                     3.960000e+01  5.537500e+01  8.260000e+01
# land_area                             1.484600e+02  4.300000e+02  9.640000e+02
# armed_forces_size                     2.850000e+01  1.282500e+02  9.360000e+02
# birth_rate                            1.795000e+01  2.875000e+01  4.608000e+01
# calling_code                          2.555000e+02  5.067500e+02  1.876000e+03
# co2-emissions                         3.447700e+01  1.850305e+02  7.279730e+02
# cpi                                   1.247400e+02  1.559250e+02  5.509300e+02
# cpi_change                            2.300000e+00  4.250000e+00  2.549000e+02
# fertility_rate                        2.245000e+00  3.597500e+00  6.910000e+00
# forested_area                         3.200000e+01  4.817500e+01  9.830000e+01
# gasoline_price                        9.800000e-01  1.240000e+00  2.000000e+00
# gdp                                   3.438723e+10  2.340940e+11  2.142770e+13
# gross_primary_education_enrollment    1.025500e+02  1.080250e+02  1.425000e+02
# gross_tertiary_education_enrollment   3.120000e+01  6.315000e+01  1.366000e+02
# infant_mortality                      1.400000e+01  3.270000e+01  8.450000e+01
# life_expectancy                       7.320000e+01  7.750000e+01  8.540000e+01
# maternal_mortality_ratio              5.300000e+01  1.860000e+02  1.150000e+03
# minimum_wage                          1.045000e+00  2.447500e+00  1.359000e+01
# out_of_pocket_health_expenditure      3.070000e+01  4.397500e+01  8.160000e+01
# physicians_per_thousand               1.460000e+00  2.935000e+00  8.420000e+00
# population                            2.150560e+02  5.561625e+02  9.735600e+02
# population_labor_force_participation  6.245000e+01  6.950000e+01  8.680000e+01
# tax_revenue                           1.630000e+01  2.110000e+01  3.720000e+01
# total_tax_rate                        3.720000e+01  4.800000e+01  2.196000e+02
# unemployment_rate                     5.360000e+00  9.490000e+00  2.818000e+01
# urban_population                      1.790390e+02  4.177650e+02  9.848120e+02
# latitude                              1.727385e+01  4.012460e+01  6.496305e+01
# longitude                             2.097265e+01  4.828152e+01  1.780650e+02

# %% [markdown]
# - Identifica el país con la mayor densidad de población y el país con la menor población en el conjunto de datos.

# %%
df_pais = df.groupby("country")["density"].max()
df_pais
# Out:
# country
# Afghanistan     60.0
# Albania        105.0
# Algeria         18.0
# Andorra        164.0
# Angola          26.0
#                ...
# Venezuela       32.0
# Vietnam        314.0
# Yemen           56.0
# Zambia          25.0
# Zimbabwe        38.0
# Name: density, Length: 195, dtype: float64

# %%
df[["country", "density"]].max()
# Out:
# country    Zimbabwe
# density       847.0
# dtype: object

# %%
df[["country", "population"]].min()
# Out:
# country       Afghanistan
# population         10.084
# dtype: object

# %% [markdown]
# - Calcula la tasa promedio de natalidad (birth_rate) para todos los países en el conjunto de datos.

# %%
df.groupby("country")["birth_rate"].mean().reset_index().sort_values(by="birth_rate", ascending=False)
# Out:
#                               country  birth_rate
# 121                             Niger       46.08
# 32                               Chad       42.17
# 157                           Somalia       41.75
# 102                              Mali       41.54
# 42   Democratic Republic of the Congo       41.18
# ..                                ...         ...
# 116                             Nauru         NaN
# 124                   North Macedonia         NaN
# 129    Palestinian National Authority         NaN
# 180                            Tuvalu         NaN
# 189                      Vatican City         NaN
#
# [195 rows x 2 columns]

# %% [markdown]
#   - Realiza un análisis de la mortalidad infantil (infant_mortality) y clasifica los países en tres categorías: baja, moderada y alta mortalidad infantil.

# %%
df["infant_mortality_2"] = pd.cut(df["infant_mortality"], bins= 3, labels= ["baja", "moderada", "alta"])
df[["country", "infant_mortality", "infant_mortality_2"]].sort_values(by="infant_mortality", ascending=False)
# Out:
#                             country  infant_mortality infant_mortality_2
# 33         Central African Republic              84.5               alta
# 155                    Sierra Leone              78.5               alta
# 160                         Somalia              76.6               alta
# 126                         Nigeria              75.7               alta
# 34                             Chad              71.4               alta
# ..                              ...               ...                ...
# 73                     Vatican City               NaN                NaN
# 98                    Liechtenstein               NaN                NaN
# 120                           Nauru               NaN                NaN
# 128                 North Macedonia               NaN                NaN
# 133  Palestinian National Authority               NaN                NaN
#
# [195 rows x 3 columns]

# %% [markdown]
# - Calcula la correlación entre las variables de "fertility_rate" y "life_expectancy". Interpreta la relación entre estas dos variables. ¿Qué tipo de correlación hay? Explica la razón de esta relación

# %%
df_corr = df[["fertility_rate", "life_expectancy"]].corr(method="spearman")
df_corr
# Out:
#                  fertility_rate  life_expectancy
# fertility_rate         1.000000        -0.843047
# life_expectancy       -0.843047         1.000000

# %%
plt.figure(figsize = (5, 5))

mask = np.triu(np.ones_like(df_corr, dtype=bool))


# convertimos nuestra matriz de correlación a una gráfica
sns.heatmap(df_corr, # sobre que datos queremos hacer el heatmap
            annot = True, # para que nos muestre los valores de cada una de las celdas del heatmap
            fmt = ".2f",  # para que nos redondee a dos decimales
            cmap = "mako", # para establecer el color de la gráfica
            vmax = 1, # para indicar cual es el valor máximo de nuestra escala de colores
            vmin = -1,
            mask =mask); # para identificar el valor mínimo de nuestra escala de colores

# %%
sns.regplot(x = "fertility_rate", 
            y = "life_expectancy", 
            data = df, 
            marker = "d")

# cambiamos los nombres de los ejes como hemos estado haciendo hasta ahora
plt.xlabel("Tasa de fertilidad")
plt.ylabel("Esperanza de vida")

# ponemos título a la gráfica
plt.title("Relación entre tassa de fertilidad y esperanza de vida");

# %%
sns.scatterplot(x = "fertility_rate", 
                y = "life_expectancy", 
                data = df, 
                size = 5, 
                marker= "v", 
                color = "orange",
                hue= "continent")


# cambiamos los nombres de los ejes
plt.xlabel("Tasa de fertilidad")
plt.ylabel("Esperanza de vida");

# %% [markdown]
# - Visualiza la distribución de la variable "cpi" utilizando un histograma y comenta sobre la distribución de los índices de percepción de corrupción.
#
# - Encuentra el país con la mayor diferencia entre el "gdp" (Producto Interno Bruto) y el "co2-emissions" (emisiones de dióxido de carbono).
#
# - Calcula el porcentaje promedio de personas que participan en la fuerza laboral(population_labor_force_participation) para todos los países.
#
# - Genera un mapa de calor (heatmap) de la matriz de correlación de todas las variables numéricas y discute las relaciones más destacadas.
#
# Recuerda proporcionar interpretaciones y conclusiones basadas en los resultados obtenidos en cada paso.

# %%
sns.histplot(x = "cpi", data = df, color = "violet");

# %%
sns.boxplot(x="cpi", data= df);

# %% [markdown]
# - Encuentra el país con la mayor diferencia entre el "gdp" (Producto Interno Bruto) y el "co2-emissions" (emisiones de dióxido de carbono).

# %%
df["diferencia"] = df["gdp"]- df["co2-emissions"]

df_diferencia =df[["country", "gdp", "co2-emissions", "diferencia"]].sort_values(by="diferencia", ascending=False).head(10)

# %%
df_diferencia
# Out:
#             country           gdp  co2-emissions    diferencia
# 64          Germany  3.845630e+12        727.973  3.845630e+12
# 185  United Kingdom  2.827113e+12        379.025  2.827113e+12
# 60           France  2.715518e+12        303.276  2.715518e+12
# 162     South Korea  2.029000e+12        620.302  2.029000e+12
# 83            Italy  2.001244e+12        320.411  2.001244e+12
# 23           Brazil  1.839758e+12        462.299  1.839758e+12
# 32           Canada  1.736426e+12        544.894  1.736426e+12
# 164           Spain  1.394116e+12        244.002  1.394116e+12
# 8         Australia  1.392681e+12        375.908  1.392681e+12
# 110          Mexico  1.258287e+12        486.406  1.258287e+12

# %%
plt.figure(figsize=(10, 15))
sns.barplot(x="diferencia",
            y="country",
            data=df_diferencia,
            palette="viridis")
plt.title("Relación Mayor país con diferencia de gdp y emisiones co2", fontsize=12)
plt.xlabel("Diferecia", fontsize=9)
plt.ylabel("País de origen", fontsize=9)  
plt.show()

# %% [markdown]
# - Calcula el porcentaje promedio de personas que participan en la fuerza laboral(population_labor_force_participation) para todos los países.

# %%
df_fuerza_laboral = df.groupby("country")["population_labor_force_participation"].mean().dropna().reset_index().head(10)

# %%
df_fuerza_laboral
# Out:
#        country  population_labor_force_participation
# 0  Afghanistan                                  48.9
# 1      Albania                                  55.7
# 2      Algeria                                  41.2
# 3       Angola                                  77.5
# 4    Argentina                                  61.3
# 5      Armenia                                  55.6
# 6    Australia                                  65.5
# 7      Austria                                  60.7
# 8   Azerbaijan                                  66.5
# 9      Bahrain                                  73.4

# %%
colores = sns.color_palette("pastel") # paleta de colores de seaborn
plt.pie("population_labor_force_participation", labels= "country",
        data = df_fuerza_laboral, 
        autopct= '%1.1f%%',
        colors = colores, 
        textprops={'fontsize': 10}, 
        startangle=90,
        wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' }) # mejora en los bordes
plt.title("Porcentaje de países con población que participan en la fuerza laboral", fontsize=9) # mejora en el titulo
plt.show()

# %% [markdown]
# - Genera un mapa de calor (heatmap) de la matriz de correlación de todas las variables numéricas y discute las relaciones más destacadas.

# %%
df_numeric = df.select_dtypes(include=['number'])

# %%
df_corr_3 = df_numeric.corr(method="spearman")
df_corr_3
# Out:
#                                        density  agricultural_land  land_area  \
# density                               1.000000           0.200302  -0.220539
# agricultural_land                     0.200302           1.000000   0.022158
# land_area                            -0.220539           0.022158   1.000000
# armed_forces_size                     0.125936           0.173127   0.384287
# birth_rate                           -0.176731           0.173660   0.178757
# calling_code                         -0.109384          -0.036252  -0.242378
# co2-emissions                         0.209351           0.015142   0.166552
# cpi                                  -0.119915           0.249278   0.136854
# cpi_change                           -0.138960           0.232981   0.224723
# fertility_rate                       -0.176856           0.164436   0.175796
# forested_area                        -0.015206          -0.382159  -0.008680
# gasoline_price                        0.104546           0.031457  -0.089567
# gdp                                  -0.004021           0.078430   0.171319
# gross_primary_education_enrollment    0.033382          -0.060903   0.022693
# gross_tertiary_education_enrollment  -0.012201          -0.132087  -0.071133
# infant_mortality                     -0.095937           0.200319   0.222185
# life_expectancy                       0.135093          -0.221712  -0.176727
# maternal_mortality_ratio             -0.098955           0.146761   0.179866
# minimum_wage                          0.061765          -0.191189  -0.097304
# out_of_pocket_health_expenditure      0.014885           0.111157   0.112200
# physicians_per_thousand               0.026946          -0.080401  -0.210800
# population                           -0.511743          -0.140550  -0.398381
# population_labor_force_participation -0.090923          -0.150819   0.033388
# tax_revenue                           0.094292          -0.072350  -0.209875
# total_tax_rate                        0.023721           0.159252   0.162818
# unemployment_rate                    -0.152447           0.055847   0.005533
# urban_population                     -0.359084          -0.025796  -0.485771
# latitude                              0.116068           0.004682  -0.158250
# longitude                             0.021248          -0.012907   0.047216
# diferencia                            0.006759           0.075940   0.129286
#
#                                       armed_forces_size  birth_rate  \
# density                                        0.125936   -0.176731
# agricultural_land                              0.173127    0.173660
# land_area                                      0.384287    0.178757
# armed_forces_size                              1.000000   -0.118602
# birth_rate                                    -0.118602    1.000000
# calling_code                                  -0.241026    0.164103
# co2-emissions                                  0.477055   -0.246307
# cpi                                            0.094123    0.391884
# cpi_change                                     0.084370    0.237546
# fertility_rate                                -0.095454    0.980987
# forested_area                                 -0.153847   -0.084387
# gasoline_price                                -0.197941   -0.302687
# gdp                                            0.696120   -0.416506
# gross_primary_education_enrollment            -0.000946    0.064180
# gross_tertiary_education_enrollment            0.255177   -0.787452
# infant_mortality                              -0.104961    0.895507
# life_expectancy                                0.162024   -0.859974
# maternal_mortality_ratio                      -0.130828    0.856945
# minimum_wage                                   0.097284   -0.657015
# out_of_pocket_health_expenditure               0.259397    0.245818
# physicians_per_thousand                        0.120254   -0.845314
# population                                     0.806751    0.349382
# population_labor_force_participation          -0.121036    0.213206
# tax_revenue                                   -0.234878   -0.397999
# total_tax_rate                                 0.162857    0.168458
# unemployment_rate                             -0.090453   -0.055770
# urban_population                               0.476780    0.106992
# latitude                                       0.123754   -0.596338
# longitude                                      0.234507    0.040054
# diferencia                                     0.692158   -0.431593
#
#                                       calling_code  co2-emissions       cpi  \
# density                                  -0.109384       0.209351 -0.119915
# agricultural_land                        -0.036252       0.015142  0.249278
# land_area                                -0.242378       0.166552  0.136854
# armed_forces_size                        -0.241026       0.477055  0.094123
# birth_rate                                0.164103      -0.246307  0.391884
# calling_code                              1.000000      -0.265872  0.105980
# co2-emissions                            -0.265872       1.000000 -0.142751
# cpi                                       0.105980      -0.142751  1.000000
# cpi_change                               -0.016856      -0.131654  0.804287
# fertility_rate                            0.164907      -0.205801  0.359507
# forested_area                            -0.085191       0.003200 -0.091008
# gasoline_price                           -0.143463       0.031760 -0.325114
# gdp                                      -0.356442       0.300473  0.008686
# gross_primary_education_enrollment       -0.068676       0.080741  0.149329
# gross_tertiary_education_enrollment      -0.227563       0.266869 -0.291723
# infant_mortality                          0.106171      -0.254783  0.419904
# life_expectancy                          -0.154025       0.261146 -0.422903
# maternal_mortality_ratio                  0.051555      -0.292307  0.415222
# minimum_wage                             -0.151760       0.378285 -0.475015
# out_of_pocket_health_expenditure         -0.054249      -0.180222  0.185645
# physicians_per_thousand                  -0.074278       0.192914 -0.293830
# population                                0.047469      -0.345963  0.219941
# population_labor_force_participation      0.084262      -0.148427  0.039076
# tax_revenue                               0.005102       0.023486 -0.320285
# total_tax_rate                           -0.334636       0.065845  0.092007
# unemployment_rate                        -0.091476      -0.002232  0.023119
# urban_population                         -0.163097      -0.349605  0.265291
# latitude                                 -0.043635       0.136520 -0.261395
# longitude                                 0.304064       0.060003  0.164743
# diferencia                               -0.315823       0.300473 -0.004117
#
#                                       cpi_change  fertility_rate  \
# density                                -0.138960       -0.176856
# agricultural_land                       0.232981        0.164436
# land_area                               0.224723        0.175796
# armed_forces_size                       0.084370       -0.095454
# birth_rate                              0.237546        0.980987
# calling_code                           -0.016856        0.164907
# co2-emissions                          -0.131654       -0.205801
# cpi                                     0.804287        0.359507
# cpi_change                              1.000000        0.216461
# fertility_rate                          0.216461        1.000000
# forested_area                          -0.033153       -0.071624
# gasoline_price                         -0.146547       -0.280087
# gdp                                     0.020980       -0.417396
# gross_primary_education_enrollment      0.043075        0.050522
# gross_tertiary_education_enrollment    -0.173455       -0.760185
# infant_mortality                        0.283011        0.867469
# life_expectancy                        -0.314851       -0.843047
# maternal_mortality_ratio                0.273891        0.830900
# minimum_wage                           -0.320803       -0.604140
# out_of_pocket_health_expenditure        0.155117        0.187757
# physicians_per_thousand                -0.187636       -0.817209
# population                              0.201357        0.174954
# population_labor_force_participation   -0.048238        0.191111
# tax_revenue                            -0.237048       -0.391246
# total_tax_rate                          0.095983        0.171121
# unemployment_rate                       0.159493       -0.071483
# urban_population                        0.153673       -0.020917
# latitude                               -0.103437       -0.578658
# longitude                               0.034444        0.037592
# diferencia                             -0.010097       -0.418319
#
#                                       forested_area  gasoline_price       gdp  \
# density                                   -0.015206        0.104546 -0.004021
# agricultural_land                         -0.382159        0.031457  0.078430
# land_area                                 -0.008680       -0.089567  0.171319
# armed_forces_size                         -0.153847       -0.197941  0.696120
# birth_rate                                -0.084387       -0.302687 -0.416506
# calling_code                              -0.085191       -0.143463 -0.356442
# co2-emissions                              0.003200        0.031760  0.300473
# cpi                                       -0.091008       -0.325114  0.008686
# cpi_change                                -0.033153       -0.146547  0.020980
# fertility_rate                            -0.071624       -0.280087 -0.417396
# forested_area                              1.000000        0.176439 -0.130333
# gasoline_price                             0.176439        1.000000 -0.061793
# gdp                                       -0.130333       -0.061793  1.000000
# gross_primary_education_enrollment         0.115076       -0.067729 -0.048303
# gross_tertiary_education_enrollment        0.008781        0.142620  0.561137
# infant_mortality                          -0.039304       -0.329678 -0.460623
# life_expectancy                           -0.004225        0.330124  0.510301
# maternal_mortality_ratio                   0.026983       -0.259473 -0.513737
# minimum_wage                               0.063705        0.367641  0.333509
# out_of_pocket_health_expenditure          -0.185938       -0.302229  0.006786
# physicians_per_thousand                   -0.060867        0.220617  0.458335
# population                                 0.022136       -0.436522  0.512638
# population_labor_force_participation       0.160070       -0.074112 -0.135170
# tax_revenue                                0.097872        0.429833 -0.170686
# total_tax_rate                             0.103458        0.050748  0.064171
# unemployment_rate                         -0.075399        0.042535 -0.110302
# urban_population                          -0.098520       -0.276560  0.643083
# latitude                                  -0.181805        0.173762  0.361887
# longitude                                 -0.078330       -0.167560  0.034177
# diferencia                                -0.169117       -0.027898  1.000000
#
#                                       gross_primary_education_enrollment  \
# density                                                         0.033382
# agricultural_land                                              -0.060903
# land_area                                                       0.022693
# armed_forces_size                                              -0.000946
# birth_rate                                                      0.064180
# calling_code                                                   -0.068676
# co2-emissions                                                   0.080741
# cpi                                                             0.149329
# cpi_change                                                      0.043075
# fertility_rate                                                  0.050522
# forested_area                                                   0.115076
# gasoline_price                                                 -0.067729
# gdp                                                            -0.048303
# gross_primary_education_enrollment                              1.000000
# gross_tertiary_education_enrollment                            -0.072752
# infant_mortality                                                0.061196
# life_expectancy                                                -0.027108
# maternal_mortality_ratio                                        0.093370
# minimum_wage                                                   -0.071331
# out_of_pocket_health_expenditure                               -0.117978
# physicians_per_thousand                                        -0.097356
# population                                                     -0.314733
# population_labor_force_participation                            0.164935
# tax_revenue                                                     0.036438
# total_tax_rate                                                  0.002829
# unemployment_rate                                              -0.075297
# urban_population                                               -0.194256
# latitude                                                       -0.198393
# longitude                                                      -0.080095
# diferencia                                                     -0.040561
#
#                                       gross_tertiary_education_enrollment  \
# density                                                         -0.012201
# agricultural_land                                               -0.132087
# land_area                                                       -0.071133
# armed_forces_size                                                0.255177
# birth_rate                                                      -0.787452
# calling_code                                                    -0.227563
# co2-emissions                                                    0.266869
# cpi                                                             -0.291723
# cpi_change                                                      -0.173455
# fertility_rate                                                  -0.760185
# forested_area                                                    0.008781
# gasoline_price                                                   0.142620
# gdp                                                              0.561137
# gross_primary_education_enrollment                              -0.072752
# gross_tertiary_education_enrollment                              1.000000
# infant_mortality                                                -0.836312
# life_expectancy                                                  0.779635
# maternal_mortality_ratio                                        -0.816563
# minimum_wage                                                     0.614777
# out_of_pocket_health_expenditure                                -0.153099
# physicians_per_thousand                                          0.811344
# population                                                      -0.288543
# population_labor_force_participation                            -0.190252
# tax_revenue                                                      0.324632
# total_tax_rate                                                  -0.033972
# unemployment_rate                                                0.121576
# urban_population                                                -0.148701
# latitude                                                         0.512269
# longitude                                                       -0.053668
# diferencia                                                       0.557862
#
#                                       infant_mortality  life_expectancy  \
# density                                      -0.095937         0.135093
# agricultural_land                             0.200319        -0.221712
# land_area                                     0.222185        -0.176727
# armed_forces_size                            -0.104961         0.162024
# birth_rate                                    0.895507        -0.859974
# calling_code                                  0.106171        -0.154025
# co2-emissions                                -0.254783         0.261146
# cpi                                           0.419904        -0.422903
# cpi_change                                    0.283011        -0.314851
# fertility_rate                                0.867469        -0.843047
# forested_area                                -0.039304        -0.004225
# gasoline_price                               -0.329678         0.330124
# gdp                                          -0.460623         0.510301
# gross_primary_education_enrollment            0.061196        -0.027108
# gross_tertiary_education_enrollment          -0.836312         0.779635
# infant_mortality                              1.000000        -0.926251
# life_expectancy                              -0.926251         1.000000
# maternal_mortality_ratio                      0.926412        -0.888506
# minimum_wage                                 -0.728351         0.738016
# out_of_pocket_health_expenditure              0.354060        -0.331019
# physicians_per_thousand                      -0.861802         0.807471
# population                                    0.189845        -0.151624
# population_labor_force_participation          0.168563        -0.157346
# tax_revenue                                  -0.404876         0.377483
# total_tax_rate                                0.188124        -0.166392
# unemployment_rate                            -0.019664         0.025251
# urban_population                              0.091764        -0.082911
# latitude                                     -0.593053         0.522420
# longitude                                     0.062883        -0.114904
# diferencia                                   -0.486011         0.532022
#
#                                       maternal_mortality_ratio  minimum_wage  \
# density                                              -0.098955      0.061765
# agricultural_land                                     0.146761     -0.191189
# land_area                                             0.179866     -0.097304
# armed_forces_size                                    -0.130828      0.097284
# birth_rate                                            0.856945     -0.657015
# calling_code                                          0.051555     -0.151760
# co2-emissions                                        -0.292307      0.378285
# cpi                                                   0.415222     -0.475015
# cpi_change                                            0.273891     -0.320803
# fertility_rate                                        0.830900     -0.604140
# forested_area                                         0.026983      0.063705
# gasoline_price                                       -0.259473      0.367641
# gdp                                                  -0.513737      0.333509
# gross_primary_education_enrollment                    0.093370     -0.071331
# gross_tertiary_education_enrollment                  -0.816563      0.614777
# infant_mortality                                      0.926412     -0.728351
# life_expectancy                                      -0.888506      0.738016
# maternal_mortality_ratio                              1.000000     -0.705657
# minimum_wage                                         -0.705657      1.000000
# out_of_pocket_health_expenditure                      0.316736     -0.429950
# physicians_per_thousand                              -0.863748      0.617181
# population                                            0.223378     -0.505065
# population_labor_force_participation                  0.234269     -0.235050
# tax_revenue                                          -0.395318      0.352840
# total_tax_rate                                        0.194811     -0.090188
# unemployment_rate                                    -0.036739      0.108471
# urban_population                                      0.052398     -0.281010
# latitude                                             -0.635555      0.344694
# longitude                                            -0.035993     -0.126924
# diferencia                                           -0.513027      0.362286
#
#                                       out_of_pocket_health_expenditure  \
# density                                                       0.014885
# agricultural_land                                             0.111157
# land_area                                                     0.112200
# armed_forces_size                                             0.259397
# birth_rate                                                    0.245818
# calling_code                                                 -0.054249
# co2-emissions                                                -0.180222
# cpi                                                           0.185645
# cpi_change                                                    0.155117
# fertility_rate                                                0.187757
# forested_area                                                -0.185938
# gasoline_price                                               -0.302229
# gdp                                                           0.006786
# gross_primary_education_enrollment                           -0.117978
# gross_tertiary_education_enrollment                          -0.153099
# infant_mortality                                              0.354060
# life_expectancy                                              -0.331019
# maternal_mortality_ratio                                      0.316736
# minimum_wage                                                 -0.429950
# out_of_pocket_health_expenditure                              1.000000
# physicians_per_thousand                                      -0.183950
# population                                                    0.144549
# population_labor_force_participation                         -0.139561
# tax_revenue                                                  -0.353469
# total_tax_rate                                                0.243631
# unemployment_rate                                             0.067540
# urban_population                                              0.269162
# latitude                                                      0.091820
# longitude                                                     0.026399
# diferencia                                                   -0.017198
#
#                                       physicians_per_thousand  population  \
# density                                              0.026946   -0.511743
# agricultural_land                                   -0.080401   -0.140550
# land_area                                           -0.210800   -0.398381
# armed_forces_size                                    0.120254    0.806751
# birth_rate                                          -0.845314    0.349382
# calling_code                                        -0.074278    0.047469
# co2-emissions                                        0.192914   -0.345963
# cpi                                                 -0.293830    0.219941
# cpi_change                                          -0.187636    0.201357
# fertility_rate                                      -0.817209    0.174954
# forested_area                                       -0.060867    0.022136
# gasoline_price                                       0.220617   -0.436522
# gdp                                                  0.458335    0.512638
# gross_primary_education_enrollment                  -0.097356   -0.314733
# gross_tertiary_education_enrollment                  0.811344   -0.288543
# infant_mortality                                    -0.861802    0.189845
# life_expectancy                                      0.807471   -0.151624
# maternal_mortality_ratio                            -0.863748    0.223378
# minimum_wage                                         0.617181   -0.505065
# out_of_pocket_health_expenditure                    -0.183950    0.144549
# physicians_per_thousand                              1.000000   -0.202343
# population                                          -0.202343    1.000000
# population_labor_force_participation                -0.224831   -0.271739
# tax_revenue                                          0.357445    0.193266
# total_tax_rate                                      -0.125991   -0.219879
# unemployment_rate                                    0.118406   -0.279644
# urban_population                                     0.032349    0.873163
# latitude                                             0.607995   -0.083488
# longitude                                           -0.061324    0.078017
# diferencia                                           0.491681    0.553782
#
#                                       population_labor_force_participation  \
# density                                                          -0.090923
# agricultural_land                                                -0.150819
# land_area                                                         0.033388
# armed_forces_size                                                -0.121036
# birth_rate                                                        0.213206
# calling_code                                                      0.084262
# co2-emissions                                                    -0.148427
# cpi                                                               0.039076
# cpi_change                                                       -0.048238
# fertility_rate                                                    0.191111
# forested_area                                                     0.160070
# gasoline_price                                                   -0.074112
# gdp                                                              -0.135170
# gross_primary_education_enrollment                                0.164935
# gross_tertiary_education_enrollment                              -0.190252
# infant_mortality                                                  0.168563
# life_expectancy                                                  -0.157346
# maternal_mortality_ratio                                          0.234269
# minimum_wage                                                     -0.235050
# out_of_pocket_health_expenditure                                 -0.139561
# physicians_per_thousand                                          -0.224831
# population                                                       -0.271739
# population_labor_force_participation                              1.000000
# tax_revenue                                                      -0.130009
# total_tax_rate                                                   -0.111521
# unemployment_rate                                                -0.493616
# urban_population                                                 -0.077016
# latitude                                                         -0.319123
# longitude                                                         0.081588
# diferencia                                                       -0.134430
#
#                                       tax_revenue  total_tax_rate  \
# density                                  0.094292        0.023721
# agricultural_land                       -0.072350        0.159252
# land_area                               -0.209875        0.162818
# armed_forces_size                       -0.234878        0.162857
# birth_rate                              -0.397999        0.168458
# calling_code                             0.005102       -0.334636
# co2-emissions                            0.023486        0.065845
# cpi                                     -0.320285        0.092007
# cpi_change                              -0.237048        0.095983
# fertility_rate                          -0.391246        0.171121
# forested_area                            0.097872        0.103458
# gasoline_price                           0.429833        0.050748
# gdp                                     -0.170686        0.064171
# gross_primary_education_enrollment       0.036438        0.002829
# gross_tertiary_education_enrollment      0.324632       -0.033972
# infant_mortality                        -0.404876        0.188124
# life_expectancy                          0.377483       -0.166392
# maternal_mortality_ratio                -0.395318        0.194811
# minimum_wage                             0.352840       -0.090188
# out_of_pocket_health_expenditure        -0.353469        0.243631
# physicians_per_thousand                  0.357445       -0.125991
# population                               0.193266       -0.219879
# population_labor_force_participation    -0.130009       -0.111521
# tax_revenue                              1.000000       -0.171187
# total_tax_rate                          -0.171187        1.000000
# unemployment_rate                        0.209264        0.026191
# urban_population                         0.026650       -0.103651
# latitude                                 0.115979       -0.026563
# longitude                               -0.128638       -0.209435
# diferencia                              -0.113719        0.031194
#
#                                       unemployment_rate  urban_population  \
# density                                       -0.152447         -0.359084
# agricultural_land                              0.055847         -0.025796
# land_area                                      0.005533         -0.485771
# armed_forces_size                             -0.090453          0.476780
# birth_rate                                    -0.055770          0.106992
# calling_code                                  -0.091476         -0.163097
# co2-emissions                                 -0.002232         -0.349605
# cpi                                            0.023119          0.265291
# cpi_change                                     0.159493          0.153673
# fertility_rate                                -0.071483         -0.020917
# forested_area                                 -0.075399         -0.098520
# gasoline_price                                 0.042535         -0.276560
# gdp                                           -0.110302          0.643083
# gross_primary_education_enrollment            -0.075297         -0.194256
# gross_tertiary_education_enrollment            0.121576         -0.148701
# infant_mortality                              -0.019664          0.091764
# life_expectancy                                0.025251         -0.082911
# maternal_mortality_ratio                      -0.036739          0.052398
# minimum_wage                                   0.108471         -0.281010
# out_of_pocket_health_expenditure               0.067540          0.269162
# physicians_per_thousand                        0.118406          0.032349
# population                                    -0.279644          0.873163
# population_labor_force_participation          -0.493616         -0.077016
# tax_revenue                                    0.209264          0.026650
# total_tax_rate                                 0.026191         -0.103651
# unemployment_rate                              1.000000         -0.131452
# urban_population                              -0.131452          1.000000
# latitude                                       0.044560         -0.004369
# longitude                                     -0.224329          0.166173
# diferencia                                    -0.112056          0.680459
#
#                                       latitude  longitude  diferencia
# density                               0.116068   0.021248    0.006759
# agricultural_land                     0.004682  -0.012907    0.075940
# land_area                            -0.158250   0.047216    0.129286
# armed_forces_size                     0.123754   0.234507    0.692158
# birth_rate                           -0.596338   0.040054   -0.431593
# calling_code                         -0.043635   0.304064   -0.315823
# co2-emissions                         0.136520   0.060003    0.300473
# cpi                                  -0.261395   0.164743   -0.004117
# cpi_change                           -0.103437   0.034444   -0.010097
# fertility_rate                       -0.578658   0.037592   -0.418319
# forested_area                        -0.181805  -0.078330   -0.169117
# gasoline_price                        0.173762  -0.167560   -0.027898
# gdp                                   0.361887   0.034177    1.000000
# gross_primary_education_enrollment   -0.198393  -0.080095   -0.040561
# gross_tertiary_education_enrollment   0.512269  -0.053668    0.557862
# infant_mortality                     -0.593053   0.062883   -0.486011
# life_expectancy                       0.522420  -0.114904    0.532022
# maternal_mortality_ratio             -0.635555  -0.035993   -0.513027
# minimum_wage                          0.344694  -0.126924    0.362286
# out_of_pocket_health_expenditure      0.091820   0.026399   -0.017198
# physicians_per_thousand               0.607995  -0.061324    0.491681
# population                           -0.083488   0.078017    0.553782
# population_labor_force_participation -0.319123   0.081588   -0.134430
# tax_revenue                           0.115979  -0.128638   -0.113719
# total_tax_rate                       -0.026563  -0.209435    0.031194
# unemployment_rate                     0.044560  -0.224329   -0.112056
# urban_population                     -0.004369   0.166173    0.680459
# latitude                              1.000000  -0.024289    0.354136
# longitude                            -0.024289   1.000000    0.017912
# diferencia                            0.354136   0.017912    1.000000

# %%
plt.figure(figsize = (25, 25))

mask = np.triu(np.ones_like(df_corr_3, dtype=bool))
sns.heatmap(df_corr_3, # sobre que datos queremos hacer el heatmap
            annot = True, # para que nos muestre los valores de cada una de las celdas del heatmap
            fmt = ".2f",  # para que nos redondee a dos decimales
            cmap = "mako", # para establecer el color de la gráfica
            vmax = 1, # para indicar cual es el valor máximo de nuestra escala de colores
            vmin = -1,
            mask=mask); # para identificar el valor mínimo de nuestra escala de colores

# %%
df.columns
# Out:
# Index(['country', 'density', 'abbreviation', 'agricultural_land', 'land_area',
#        'armed_forces_size', 'birth_rate', 'calling_code', 'capital/major_city',
#        'co2-emissions', 'cpi', 'cpi_change', 'currency-code', 'fertility_rate',
#        'forested_area', 'gasoline_price', 'gdp',
#        'gross_primary_education_enrollment',
#        'gross_tertiary_education_enrollment', 'infant_mortality',
#        'largest_city', 'life_expectancy', 'maternal_mortality_ratio',
#        'minimum_wage', 'official_language', 'out_of_pocket_health_expenditure',
#        'physicians_per_thousand', 'population',
#        'population_labor_force_participation', 'tax_revenue', 'total_tax_rate',
#        'unemployment_rate', 'urban_population', 'latitude', 'longitude',
#        'continent', 'infant_mortality_2'],
#       dtype='object')
